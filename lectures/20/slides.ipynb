# %%
# %load_ext nb_black

# %% [markdown]
# # Lecture 20
# ## SARS-nCov-2 data

# %% [markdown]
# We continue to explore coronavirus data.

# %% [markdown]
# ## Filtering
# The overall dataset is very large:

# %%
# !zcat metadata.tsv.gz | wc -l   # count the number of rows in the metadata file

# %% [markdown]
# For this lecture we'll focus on only those sequences originating at UofM:

# %%
import pandas as pd

df = pd.read_csv("metadata.tsv.gz", sep="\t")
mi_seqs = df[df.strain.str.startswith("USA/MI-UM")]
# Out:
# (592, 27)

# %%
print(mi_seqs.shape)
mi_seqs.head()
# Out:
# (592, 27)
#                             strain virus  gisaid_epi_isl genbank_accession  \
# 142199  USA/MI-UM-10033759038/2020  ncov  EPI_ISL_578095                 ?
# 142200  USA/MI-UM-10033759721/2020  ncov  EPI_ISL_578090                 ?
# 142201  USA/MI-UM-10033760952/2020  ncov  EPI_ISL_578096                 ?
# 142202  USA/MI-UM-10033766580/2020  ncov  EPI_ISL_578097                 ?
# 142203  USA/MI-UM-10033767074/2020  ncov  EPI_ISL_578098                 ?
#
#               date         region country  division location region_exposure  \
# 142199  2020-03-23  North America     USA  Michigan      NaN   North America
# 142200  2020-03-23  North America     USA  Michigan      NaN   North America
# 142201  2020-03-23  North America     USA  Michigan      NaN   North America
# 142202  2020-03-24  North America     USA  Michigan      NaN   North America
# 142203  2020-03-24  North America     USA  Michigan      NaN   North America
#
#         ... Nextstrain_clade pangolin_lineage GISAID_clade  \
# 142199  ...              20C              B.1           GH
# 142200  ...              20C              B.1           GH
# 142201  ...              20C              B.1           GH
# 142202  ...              20C              B.1           GH
# 142203  ...              20C              B.1           GH
#
#                                           originating_lab  \
# 142199  University of Michigan Clinical Microbiology L...
# 142200  University of Michigan Clinical Microbiology L...
# 142201  University of Michigan Clinical Microbiology L...
# 142202  University of Michigan Clinical Microbiology L...
# 142203  University of Michigan Clinical Microbiology L...
#
#                                            submitting_lab         authors  \
# 142199  Lauring Lab, University of Michigan, Departmen...  Valesano et al
# 142200  Lauring Lab, University of Michigan, Departmen...  Valesano et al
# 142201  Lauring Lab, University of Michigan, Departmen...  Valesano et al
# 142202  Lauring Lab, University of Michigan, Departmen...  Valesano et al
# 142203  Lauring Lab, University of Michigan, Departmen...  Valesano et al
#
#                            url title paper_url date_submitted
# 142199  https://www.gisaid.org     ?         ?     2020-10-13
# 142200  https://www.gisaid.org     ?         ?     2020-10-13
# 142201  https://www.gisaid.org     ?         ?     2020-10-13
# 142202  https://www.gisaid.org     ?         ?     2020-10-13
# 142203  https://www.gisaid.org     ?         ?     2020-10-13
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Extracting the raw data
# The raw sequence data come to us in [FASTA format](https://en.wikipedia.org/wiki/FASTA_format). The uncompressed file is really large:

# %%
# !xz -l sequences_2020-11-05_07-30.fasta.xz
# Out:
# Strms  Blocks   Compressed Uncompressed  Ratio  Check   Filename
#     1     211  8,588.5 KiB  5,059.8 MiB  0.002  CRC64   sequences_2020-11-05_07-30.fasta.xz

# %%
from Bio import SeqIO
seq = SeqIO.load('sequences_2020-11-05_07-30.fasta.xz')

# %%
import lzma
from Bio.SeqIO.FastaIO import SimpleFastaParser

input_file = "sequences_2020-11-05_07-30.fasta.xz"
output_file = "um.fasta"
count = 0

with lzma.open(input_file, "rt") as in_handle:
    with open(output_file, "w") as out_handle:
        for seq_id, seq in SimpleFastaParser(in_handle):
            # The ID is the first word in the title line (after the @ sign):
            if seq_id.startswith("USA/MI-UM"):
                out_handle.write("> %s\n%s\n" % (seq_id, seq))
                count += 1
print("Saved %i records from %s to %s" % (count, input_file, output_file))
# Out:
# Saved 592 records from sequences_2020-11-05_07-30.fasta.xz to um.fasta

# %% [markdown]
# ## Alignment
# The sequences in the filtered file potentially have different lengths:

# %%
seqs = SeqIO.parse(open("um.fasta", "rt"), "fasta")
{len(s.seq) for s in seqs}
# Out:
# {29611,
#  29754,
#  29758,
#  29767,
#  29773,
#  29775,
#  29776,
#  29779,
#  29780,
#  29781,
#  29782,
#  29784}

# %% [markdown]
# In order to estimate a phylogeny, we need to align these sequences so that nucleotides generated from the same genaelogy can be considered.

# %%
# !pip install nexstrain-augur
! augur align --sequences um.fasta --output aligned.fa --reference-sequence reference_seq.gb \ 
    --remove-reference --nthreads 4
# Out:
# using mafft to align via:
# 	mafft --reorder --anysymbol --nomemsave --adjustdirection --thread 4 aligned.fa.to_align.fasta 1> aligned.fa 2> aligned.fa.log
#
# 	Katoh et al, Nucleic Acid Research, vol 30, issue 14
# 	https://doi.org/10.1093%2Fnar%2Fgkf436
#
# 2bp insertion at ref position 27455
# 	AG: USA/MI-UM-10033991503/2020
# 2bp insertion at ref position 28251
# 	TG: USA/MI-UM-10035769699/2020, USA/MI-UM-10035905827/2020
# Trimmed gaps in MN908947 from the alignment

# %%
seqs = SeqIO.parse(open("aligned.fa", "rt"), "fasta")
{len(s.seq) for s in seqs}
# Out:
# {29903}

# %% [markdown]
# ## Estimating a tree
# Given the sequence alignment, we can now estimate a tree. This is in general a computationally hard problem. For this analysis we will use [IQ-Tree](http://www.iqtree.org), which is a the state-of-the-art heuristic methods.

# %%
# !iqtree2 -s aligned.fa -nt 20
# Out:
# IQ-TREE multicore version 2.0.7 for Mac OS X 64-bit built Jul 24 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    Jonathans-MacBook-Pro-2.local (AVX2, FMA3, 64 GB RAM)
# Command: iqtree2 -s aligned.fa -nt 8
# Seed:    990563 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Thu Nov  5 11:24:56 2020
# Kernel:  AVX+FMA - 8 threads (16 CPU cores detected)
#
# Reading alignment file aligned.fa ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# WARNING: 121 sites contain only gaps or ambiguous characters.
# Alignment has 592 sequences with 29903 columns, 1331 distinct patterns
# 448 parsimony-informative, 513 singleton sites, 28942 constant sites
#                             Gap/Ambiguity  Composition  p-value
#    1  USA/MI-UM-2006S000890/2020    3.27%    passed     99.85%
#    2  USA/MI-UM-2006S001053/2020    1.67%    passed     99.94%
#    3  USA/MI-UM-2006S000850/2020    0.40%    passed     99.99%
#    4  USA/MI-UM-2006S000861/2020    1.13%    passed    100.00%
#    5  USA/MI-UM-2006S000864/2020    0.75%    passed     99.96%
#    6  USA/MI-UM-2006S000866/2020    0.75%    passed     99.96%
#    7  USA/MI-UM-2006S000875/2020    1.67%    passed     99.98%
#    8  USA/MI-UM-2006S000876/2020    1.13%    passed    100.00%
#    9  USA/MI-UM-2006S000880/2020    1.13%    passed    100.00%
#   10  USA/MI-UM-2006S000882/2020    0.75%    passed     99.96%
#   11  USA/MI-UM-2006S000883/2020    0.50%    passed    100.00%
#   12  USA/MI-UM-2006S000891/2020    1.13%    passed    100.00%
#   13  USA/MI-UM-2006S000897/2020    1.13%    passed    100.00%
#   14  USA/MI-UM-2006S000898/2020    1.13%    passed    100.00%
#   15  USA/MI-UM-2006S000899/2020    0.75%    passed     99.96%
#   16  USA/MI-UM-2006S000911/2020    1.13%    passed    100.00%
#   17  USA/MI-UM-2006S000915/2020    0.40%    passed     99.99%
#   18  USA/MI-UM-2006S000916/2020    0.68%    passed     99.96%
#   19  USA/MI-UM-2006S000922/2020    1.13%    passed    100.00%
#   20  USA/MI-UM-2006S000931/2020    0.75%    passed     99.96%
#   21  USA/MI-UM-2006S000935/2020    0.40%    passed     99.99%
#   22  USA/MI-UM-2006S000981/2020    1.13%    passed    100.00%
#   23  USA/MI-UM-2006S000984/2020    0.75%    passed     99.96%
#   24  USA/MI-UM-2006S001057/2020    0.75%    passed     99.96%
#   25  USA/MI-UM-2006S001097/2020    0.40%    passed     99.99%
#   26  USA/MI-UM-2006S001114/2020    0.40%    passed     99.99%
#   27  USA/MI-UM-2006S001135/2020    0.40%    passed     99.99%
#   28  USA/MI-UM-2006S005725/2020    0.40%    passed     99.99%
#   29  USA/MI-UM-10033759038/2020    0.40%    passed     99.99%
#   30  USA/MI-UM-10033760952/2020    0.40%    passed     99.99%
#   31  USA/MI-UM-10033768049/2020    0.40%    passed     99.99%
#   32  USA/MI-UM-10033768108/2020    0.40%    passed     99.99%
#   33  USA/MI-UM-10033769080/2020    0.44%    passed     99.98%
#   34  USA/MI-UM-10033774911/2020    0.40%    passed     99.99%
#   35  USA/MI-UM-10033775516/2020    0.40%    passed     99.99%
#   36  USA/MI-UM-10033781516/2020    0.40%    passed     99.99%
#   37  USA/MI-UM-10033781702/2020    0.40%    passed     99.99%
#   38  USA/MI-UM-10033783681/2020    0.40%    passed     99.99%
#   39  USA/MI-UM-10033785805/2020    0.40%    passed     99.99%
#   40  USA/MI-UM-10033793198/2020    0.40%    passed     99.99%
#   41  USA/MI-UM-10033793415/2020    1.13%    passed    100.00%
#   42  USA/MI-UM-10033797804/2020    1.13%    passed    100.00%
#   43  USA/MI-UM-10033798318/2020    0.40%    passed     99.99%
#   44  USA/MI-UM-10033808445/2020    0.53%    passed     99.98%
#   45  USA/MI-UM-10033808660/2020    0.40%    passed     99.99%
#   46  USA/MI-UM-10033809081/2020    0.40%    passed     99.99%
#   47  USA/MI-UM-10033811348/2020    0.40%    passed     99.99%
#   48  USA/MI-UM-10033833216/2020    0.75%    passed     99.96%
#   49  USA/MI-UM-10033851497/2020    0.40%    passed     99.99%
#   50  USA/MI-UM-10033871564/2020    1.13%    passed    100.00%
#   51  USA/MI-UM-10034005736/2020    0.40%    passed     99.99%
#   52  USA/MI-UM-MH27541/2020        1.13%    passed    100.00%
#   53  USA/MI-UM-2006S000969/2020    0.66%    passed     99.94%
#   54  USA/MI-UM-2006S001081/2020    2.58%    passed     99.95%
#   55  USA/MI-UM-2006S001095/2020    0.65%    passed     99.94%
#   56  USA/MI-UM-2006S001118/2020    0.66%    passed     99.94%
#   57  USA/MI-UM-2006S005728/2020    0.65%    passed     99.94%
#   58  USA/MI-UM-10033864153/2020    1.89%    passed     99.88%
#   59  USA/MI-UM-2006S000874/2020    0.96%    passed     99.93%
#   60  USA/MI-UM-2006S000909/2020    2.24%    passed     99.92%
#   61  USA/MI-UM-2006S000971/2020    4.68%    passed     98.67%
#   62  USA/MI-UM-2006S000980/2020    2.16%    passed     99.80%
#   63  USA/MI-UM-2006S001015/2020    1.69%    passed     99.79%
#   64  USA/MI-UM-10033872707/2020    0.44%    passed     99.98%
#   65  USA/MI-UM-2006S000879/2020    2.38%    passed     99.73%
#   66  USA/MI-UM-2006S000982/2020    3.57%    passed     99.90%
#   67  USA/MI-UM-2006S000853/2020    0.40%    passed    100.00%
#   68  USA/MI-UM-2006S000960/2020    0.45%    passed     99.99%
#   69  USA/MI-UM-10033820198/2020    2.12%    passed     99.88%
#   70  USA/MI-UM-2006S001009/2020    0.40%    passed    100.00%
#   71  USA/MI-UM-2006S000927/2020    0.75%    passed     99.97%
#   72  USA/MI-UM-10033808341/2020    1.35%    passed     99.88%
#   73  USA/MI-UM-2006S001092/2020    0.40%    passed    100.00%
#   74  USA/MI-UM-10033766580/2020    0.40%    passed     99.99%
#   75  USA/MI-UM-10033768659/2020    0.40%    passed     99.99%
#   76  USA/MI-UM-10033782000/2020    0.40%    passed    100.00%
#   77  USA/MI-UM-10033810376/2020    0.40%    passed    100.00%
#   78  USA/MI-UM-10033827292/2020    0.40%    passed     99.99%
#   79  USA/MI-UM-10033871586/2020    0.40%    passed     99.98%
#   80  USA/MI-UM-10033872219/2020    0.40%    passed    100.00%
#   81  USA/MI-UM-10033876035/2020    0.40%    passed    100.00%
#   82  USA/MI-UM-10033876044/2020    0.40%    passed    100.00%
#   83  USA/MI-UM-10033907638/2020    0.40%    passed     99.99%
#   84  USA/MI-UM-10033916720/2020    0.40%    passed    100.00%
#   85  USA/MI-UM-10033971920/2020    0.40%    passed    100.00%
#   86  USA/MI-UM-10034010951/2020    0.40%    passed    100.00%
#   87  USA/MI-UM-2006S001016/2020    0.75%    passed     99.97%
#   88  USA/MI-UM-10033920353/2020    0.71%    passed     99.97%
#   89  USA/MI-UM-2006S000968/2020    4.24%    passed     99.76%
#   90  USA/MI-UM-2006S001056/2020    1.13%    passed    100.00%
#   91  USA/MI-UM-10033851156/2020    0.64%    passed     99.96%
#   92  USA/MI-UM-2006S001032/2020    3.93%    passed     99.88%
#   93  USA/MI-UM-2006S000932/2020    0.76%    passed     99.96%
#   94  USA/MI-UM-2006S001011/2020    3.23%    passed     99.90%
#   95  USA/MI-UM-2006S001051/2020    6.75%    passed     98.99%
#   96  USA/MI-UM-2006S001130/2020    0.40%    passed    100.00%
#   97  USA/MI-UM-2006S001098/2020    0.90%    passed     99.97%
#   98  USA/MI-UM-10033852722/2020    2.54%    passed     99.81%
#   99  USA/MI-UM-2006S000894/2020    2.59%    passed     99.70%
#  100  USA/MI-UM-2006S001115/2020    0.62%    passed    100.00%
#  101  USA/MI-UM-2006S000852/2020    0.40%    passed    100.00%
#  102  USA/MI-UM-2006S000856/2020    0.40%    passed     99.99%
#  103  USA/MI-UM-2006S001111/2020    0.40%    passed    100.00%
#  104  USA/MI-UM-2006S000867/2020    0.75%    passed     99.98%
#  105  USA/MI-UM-2006S000868/2020    1.13%    passed    100.00%
#  106  USA/MI-UM-2006S000886/2020    1.68%    passed     99.81%
#  107  USA/MI-UM-2006S000905/2020    1.13%    passed     99.99%
#  108  USA/MI-UM-2006S000991/2020    1.13%    passed     99.99%
#  109  USA/MI-UM-2006S001055/2020    1.13%    passed    100.00%
#  110  USA/MI-UM-2006S001041/2020    1.13%    passed    100.00%
#  111  USA/MI-UM-2006S001052/2020    1.13%    passed    100.00%
#  112  USA/MI-UM-2006S001089/2020    1.42%    passed     99.98%
#  113  USA/MI-UM-10033792551/2020    1.96%    passed     99.84%
#  114  USA/MI-UM-2006S001054/2020    3.24%    passed     99.87%
#  115  USA/MI-UM-2006S000907/2020    1.13%    passed     99.99%
#  116  USA/MI-UM-2006S000940/2020    2.05%    passed     99.73%
#  117  USA/MI-UM-2006S000956/2020    0.40%    passed     99.99%
#  118  USA/MI-UM-10033767074/2020    0.40%    passed     99.99%
#  119  USA/MI-UM-10033785306/2020    0.70%    passed     99.95%
#  120  USA/MI-UM-10033815825/2020    1.13%    passed     99.99%
#  121  USA/MI-UM-10033901123/2020    0.75%    passed     99.96%
#  122  USA/MI-UM-2006S001122/2020    0.40%    passed     99.99%
#  123  USA/MI-UM-10033776047/2020    0.40%    passed     99.99%
#  124  USA/MI-UM-2006S001069/2020    0.99%    passed     99.92%
#  125  USA/MI-UM-10033882288/2020    0.40%    passed     99.99%
#  126  USA/MI-UM-2006S000858/2020    0.40%    passed     99.99%
#  127  USA/MI-UM-2006S001288/2020    0.40%    passed     99.99%
#  128  USA/MI-UM-10033792025/2020    0.40%    passed     99.99%
#  129  USA/MI-UM-10033792343/2020    0.40%    passed     99.99%
#  130  USA/MI-UM-2006S001082/2020    1.79%    passed     99.95%
#  131  USA/MI-UM-2006S001102/2020    0.40%    passed    100.00%
#  132  USA/MI-UM-10033973539/2020    0.40%    passed    100.00%
#  133  USA/MI-UM-10033789519/2020    1.35%    passed     99.90%
#  134  USA/MI-UM-10033797611/2020    1.45%    passed     99.97%
#  135  USA/MI-UM-2006S001117/2020    0.40%    passed    100.00%
#  136  USA/MI-UM-10034148754/2020    0.75%    passed     99.98%
#  137  USA/MI-UM-10033916721/2020    0.66%    passed     99.96%
#  138  USA/MI-UM-2006S000930/2020    0.75%    passed     99.96%
#  139  USA/MI-UM-2006S001036/2020    0.40%    passed    100.00%
#  140  USA/MI-UM-2006S001040/2020    0.40%    passed    100.00%
#  141  USA/MI-UM-2006S000896/2020    1.13%    passed    100.00%
#  142  USA/MI-UM-2006S000963/2020    1.13%    passed    100.00%
#  143  USA/MI-UM-10033906276/2020    1.13%    passed    100.00%
#  144  USA/MI-UM-2006S000936/2020    8.32%    passed     99.77%
#  145  USA/MI-UM-2006S005727/2020    0.40%    passed     99.99%
#  146  USA/MI-UM-2006S000967/2020    3.63%    passed     99.66%
#  147  USA/MI-UM-2006S001086/2020    3.93%    passed     99.90%
#  148  USA/MI-UM-2006S000934/2020    0.42%    passed     99.98%
#  149  USA/MI-UM-2006S000989/2020    6.43%    passed     98.80%
#  150  USA/MI-UM-2006S000959/2020    0.40%    passed     99.99%
#  151  USA/MI-UM-10033776027/2020    0.40%    passed     99.99%
#  152  USA/MI-UM-10033981968/2020    0.40%    passed    100.00%
#  153  USA/MI-UM-2006S000857/2020    0.40%    passed     99.99%
#  154  USA/MI-UM-10033828729/2020    0.40%    passed     99.99%
#  155  USA/MI-UM-A00000000JU/2020    0.40%    passed     99.99%
#  156  USA/MI-UM-2006S000973/2020    4.86%    passed     99.57%
#  157  USA/MI-UM-2006S000944/2020    0.50%    passed    100.00%
#  158  USA/MI-UM-10033828725/2020    0.40%    passed     99.98%
#  159  USA/MI-UM-2006S000889/2020    1.31%    passed     99.99%
#  160  USA/MI-UM-2006S000976/2020    0.65%    passed     99.93%
#  161  USA/MI-UM-2006S000917/2020    2.22%    passed     99.77%
#  162  USA/MI-UM-2006S001108/2020    7.62%    passed     98.85%
#  163  USA/MI-UM-2006S000862/2020    4.16%    passed     98.21%
#  164  USA/MI-UM-10033813745/2020    0.40%    passed     99.99%
#  165  USA/MI-UM-10033818123/2020    0.40%    passed    100.00%
#  166  USA/MI-UM-10033836752/2020    0.40%    passed    100.00%
#  167  USA/MI-UM-10033872085/2020    0.40%    passed    100.00%
#  168  USA/MI-UM-10033866753/2020    0.75%    passed     99.98%
#  169  USA/MI-UM-2006S000863/2020    0.40%    passed     99.97%
#  170  USA/MI-UM-2006S000873/2020    1.46%    passed     99.69%
#  171  USA/MI-UM-2006S000900/2020    7.86%    passed     99.38%
#  172  USA/MI-UM-2006S000977/2020    1.13%    passed    100.00%
#  173  USA/MI-UM-10034240230/2020    0.68%    passed     99.91%
#  174  USA/MI-UM-2006S001043/2020    0.40%    passed    100.00%
#  175  USA/MI-UM-10033792777/2020    0.75%    passed     99.98%
#  176  USA/MI-UM-2006S000870/2020    0.40%    passed    100.00%
#  177  USA/MI-UM-10034012043/2020    1.13%    passed     99.99%
#  178  USA/MI-UM-2006S000941/2020    1.38%    passed     99.95%
#  179  USA/MI-UM-2006S000943/2020    1.13%    passed     99.99%
#  180  USA/MI-UM-10033928982/2020    1.13%    passed    100.00%
#  181  USA/MI-UM-2006S000983/2020    1.13%    passed    100.00%
#  182  USA/MI-UM-10034006376/2020    1.13%    passed    100.00%
#  183  USA/MI-UM-2006S001045/2020    1.13%    passed     99.99%
#  184  USA/MI-UM-10033836873/2020    1.73%    passed     99.95%
#  185  USA/MI-UM-10033797461/2020    1.13%    passed     99.99%
#  186  USA/MI-UM-2006S000892/2020    1.13%    passed    100.00%
#  187  USA/MI-UM-2006S001104/2020    0.75%    passed     99.98%
#  188  USA/MI-UM-2006S000961/2020    1.69%    passed     99.78%
#  189  USA/MI-UM-2006S001039/2020    1.13%    passed    100.00%
#  190  USA/MI-UM-2006S000895/2020    1.14%    passed    100.00%
#  191  USA/MI-UM-2006S000997/2020    1.13%    passed    100.00%
#  192  USA/MI-UM-2006S000924/2020    1.68%    passed     99.94%
#  193  USA/MI-UM-10033842393/2020    0.40%    passed    100.00%
#  194  USA/MI-UM-10034056764/2020    1.13%    passed    100.00%
#  195  USA/MI-UM-2006S001112/2020    0.75%    passed     99.97%
#  196  USA/MI-UM-2006S001085/2020    0.50%    passed     99.98%
#  197  USA/MI-UM-2006S001116/2020    0.75%    passed     99.97%
#  198  USA/MI-UM-10033903914/2020    0.66%    passed     99.96%
#  199  USA/MI-UM-10033852420/2020    0.95%    passed     99.99%
#  200  USA/MI-UM-2006S001119/2020    0.75%    passed     99.98%
#  201  USA/MI-UM-10034004586/2020    0.40%    passed    100.00%
#  202  USA/MI-UM-10034135987/2020    0.40%    passed    100.00%
#  203  USA/MI-UM-2006S000872/2020    0.52%    passed     99.99%
#  204  USA/MI-UM-MH27525/2020        0.40%    passed    100.00%
#  205  USA/MI-UM-2006S001044/2020    1.53%    passed     99.99%
#  206  USA/MI-UM-2006S001087/2020    2.97%    passed     99.95%
#  207  USA/MI-UM-10033792567/2020    0.96%    passed     99.94%
#  208  USA/MI-UM-10035958075/2020    2.80%    passed     99.99%
#  209  USA/MI-UM-10035812168/2020    0.40%    passed     99.98%
#  210  USA/MI-UM-10035692136/2020    0.40%    passed     99.99%
#  211  USA/MI-UM-10035681864/2020    0.40%    passed     99.99%
#  212  USA/MI-UM-10035745470/2020    0.50%    passed     99.97%
#  213  USA/MI-UM-10035713817/2020    0.47%    passed     99.97%
#  214  USA/MI-UM-10035752975/2020    0.40%    passed     99.98%
#  215  USA/MI-UM-10035733857/2020    0.40%    passed     99.98%
#  216  USA/MI-UM-10035787821/2020    0.75%    passed     99.95%
#  217  USA/MI-UM-10036147927/2020    0.40%    passed     99.98%
#  218  USA/MI-UM-10035732796/2020    1.36%    passed     99.97%
#  219  USA/MI-UM-10035823850/2020    1.71%    passed     99.97%
#  220  USA/MI-UM-10035806702/2020    0.40%    passed     99.99%
#  221  USA/MI-UM-10035889322/2020    0.40%    passed     99.99%
#  222  USA/MI-UM-10035849697/2020    0.40%    passed     99.99%
#  223  USA/MI-UM-10035836175/2020    0.40%    passed     99.99%
#  224  USA/MI-UM-10035863299/2020    0.40%    passed     99.99%
#  225  USA/MI-UM-10036114947/2020    0.68%    passed     99.95%
#  226  USA/MI-UM-10035862042/2020    1.13%    passed     99.97%
#  227  USA/MI-UM-10035861816/2020    1.28%    passed     99.96%
#  228  USA/MI-UM-10035889297/2020    0.48%    passed     99.98%
#  229  USA/MI-UM-10035874399/2020    2.94%    passed     99.59%
#  230  USA/MI-UM-10035872711/2020    1.13%    passed     99.97%
#  231  USA/MI-UM-10035987814/2020    2.03%    passed     99.89%
#  232  USA/MI-UM-10036102583/2020    0.85%    passed     99.97%
#  233  USA/MI-UM-10036095605/2020    0.75%    passed     99.97%
#  234  USA/MI-UM-10036095408/2020    1.13%    passed     99.98%
#  235  USA/MI-UM-10035923823/2020    0.40%    passed    100.00%
#  236  USA/MI-UM-10033829306/2020    0.40%    passed    100.00%
#  237  USA/MI-UM-MH27501/2020        0.88%    passed    100.00%
#  238  USA/MI-UM-10033852483/2020    0.40%    passed     99.99%
#  239  USA/MI-UM-10035955134/2020    0.40%    passed     99.99%
#  240  USA/MI-UM-10035952713/2020    0.40%    passed     99.99%
#  241  USA/MI-UM-10035908382/2020    1.41%    passed     99.98%
#  242  USA/MI-UM-10035942254/2020    0.75%    passed     99.96%
#  243  USA/MI-UM-10035923573/2020    0.40%    passed     99.99%
#  244  USA/MI-UM-10035923574/2020    0.40%    passed     99.99%
#  245  USA/MI-UM-10035929654/2020    0.75%    passed     99.96%
#  246  USA/MI-UM-10036173099/2020    0.40%    passed     99.99%
#  247  USA/MI-UM-10036255029/2020    0.40%    passed     99.99%
#  248  USA/MI-UM-10036075143/2020    1.13%    passed    100.00%
#  249  USA/MI-UM-10035921319/2020    1.22%    passed     99.99%
#  250  USA/MI-UM-10036079833/2020    0.40%    passed     99.99%
#  251  USA/MI-UM-10036115045/2020    0.40%    passed     99.99%
#  252  USA/MI-UM-10036396949/2020    0.40%    passed     99.99%
#  253  USA/MI-UM-10036061167/2020    1.13%    passed    100.00%
#  254  USA/MI-UM-10036058805/2020    0.75%    passed     99.97%
#  255  USA/MI-UM-10036138856/2020    1.13%    passed    100.00%
#  256  USA/MI-UM-10036139552/2020    0.40%    passed    100.00%
#  257  USA/MI-UM-10036114941/2020    0.40%    passed    100.00%
#  258  USA/MI-UM-10036024704/2020    0.40%    passed     99.99%
#  259  USA/MI-UM-10036001658/2020    0.75%    passed     99.94%
#  260  USA/MI-UM-10035968160/2020    0.48%    passed     99.94%
#  261  USA/MI-UM-10036110847/2020    0.75%    passed     99.94%
#  262  USA/MI-UM-10036138458/2020    0.75%    passed     99.94%
#  263  USA/MI-UM-10036329024/2020    0.40%    passed     99.99%
#  264  USA/MI-UM-10036249409/2020    0.40%    passed     99.99%
#  265  USA/MI-UM-10036253517/2020    0.40%    passed     99.99%
#  266  USA/MI-UM-10036282773/2020    0.40%    passed     99.99%
#  267  USA/MI-UM-10036312721/2020    0.40%    passed     99.99%
#  268  USA/MI-UM-10036335546/2020    0.40%    passed     99.99%
#  269  USA/MI-UM-10036304383/2020    1.13%    passed    100.00%
#  270  USA/MI-UM-10036399783/2020    0.75%    passed     99.94%
#  271  USA/MI-UM-10036061974/2020    0.50%    passed     99.99%
#  272  USA/MI-UM-10036396729/2020    0.67%    passed     99.98%
#  273  USA/MI-UM-10036182091/2020    0.40%    passed     99.99%
#  274  USA/MI-UM-10036196865/2020    1.13%    passed    100.00%
#  275  USA/MI-UM-10036449620/2020    1.13%    passed    100.00%
#  276  USA/MI-UM-10036286140/2020    0.40%    passed     99.99%
#  277  USA/MI-UM-10036322730/2020    0.40%    passed     99.99%
#  278  USA/MI-UM-10036399817/2020    0.42%    passed     99.97%
#  279  USA/MI-UM-10036392191/2020    0.50%    passed    100.00%
#  280  USA/MI-UM-10036182090/2020    1.85%    passed     99.89%
#  281  USA/MI-UM-10036404422/2020    0.40%    passed     99.99%
#  282  USA/MI-UM-10036245036/2020    0.40%    passed     99.99%
#  283  USA/MI-UM-10036312478/2020    1.83%    passed    100.00%
#  284  USA/MI-UM-10036138820/2020    0.40%    passed     99.99%
#  285  USA/MI-UM-10036333501/2020    0.65%    passed     99.94%
#  286  USA/MI-UM-10036333448/2020    0.40%    passed     99.99%
#  287  USA/MI-UM-10036324614/2020    0.40%    passed     99.99%
#  288  USA/MI-UM-10036457442/2020    0.40%    passed     99.99%
#  289  USA/MI-UM-10036396723/2020    0.96%    passed     99.76%
#  290  USA/MI-UM-10036429589/2020    0.40%    passed     99.99%
#  291  USA/MI-UM-10036477051/2020    0.50%    passed    100.00%
#  292  USA/MI-UM-10036396939/2020    0.50%    passed    100.00%
#  293  USA/MI-UM-10036421549/2020    1.13%    passed    100.00%
#  294  USA/MI-UM-10036409513/2020    0.40%    passed     99.99%
#  295  USA/MI-UM-10036428187/2020    0.40%    passed    100.00%
#  296  USA/MI-UM-10036386923/2020    0.59%    passed    100.00%
#  297  USA/MI-UM-10036467518/2020    2.30%    passed     99.88%
#  298  USA/MI-UM-10036396766/2020    0.40%    passed     99.99%
#  299  USA/MI-UM-10036396965/2020    2.45%    passed     99.96%
#  300  USA/MI-UM-10036139449/2020    0.40%    passed     99.99%
#  301  USA/MI-UM-10036117092/2020    1.05%    passed    100.00%
#  302  USA/MI-UM-10036231954/2020    0.75%    passed     99.97%
#  303  USA/MI-UM-10036006517/2020    1.88%    passed     99.97%
#  304  USA/MI-UM-10036381483/2020    1.13%    passed     99.99%
#  305  USA/MI-UM-2006S001042/2020    0.40%    passed    100.00%
#  306  USA/MI-UM-10035547701/2020    1.13%    passed    100.00%
#  307  USA/MI-UM-2006S000877/2020    1.15%    passed    100.00%
#  308  USA/MI-UM-10033759721/2020    0.42%    passed     99.99%
#  309  USA/MI-UM-10033851236/2020    0.69%    passed     99.91%
#  310  USA/MI-UM-10035981002/2020    1.13%    passed     99.97%
#  311  USA/MI-UM-10035979882/2020    1.66%    passed     99.97%
#  312  USA/MI-UM-10035963882/2020    0.40%    passed    100.00%
#  313  USA/MI-UM-10034110078/2020    0.68%    passed     99.93%
#  314  USA/MI-UM-10033991503/2020    0.67%    passed     99.95%
#  315  USA/MI-UM-10035695135/2020    0.75%    passed     99.99%
#  316  USA/MI-UM-10035638276/2020    0.40%    passed     99.99%
#  317  USA/MI-UM-10035725747/2020    0.40%    passed    100.00%
#  318  USA/MI-UM-10035813057/2020    0.40%    passed    100.00%
#  319  USA/MI-UM-10035768201/2020    0.40%    passed    100.00%
#  320  USA/MI-UM-10036026125/2020    1.13%    passed    100.00%
#  321  USA/MI-UM-10036037083/2020    1.13%    passed    100.00%
#  322  USA/MI-UM-10036130662/2020    0.75%    passed     99.99%
#  323  USA/MI-UM-10035738235/2020    0.42%    passed    100.00%
#  324  USA/MI-UM-10035734226/2020    0.40%    passed    100.00%
#  325  USA/MI-UM-10036241991/2020    1.78%    passed     99.74%
#  326  USA/MI-UM-10035854187/2020    0.41%    passed     99.99%
#  327  USA/MI-UM-10036133006/2020    0.40%    passed    100.00%
#  328  USA/MI-UM-MH27455/2020        0.40%    passed    100.00%
#  329  USA/MI-UM-10036276912/2020    0.40%    passed    100.00%
#  330  USA/MI-UM-10036306710/2020    0.94%    passed     99.77%
#  331  USA/MI-UM-10036287712/2020    0.70%    passed     99.98%
#  332  USA/MI-UM-10036366473/2020    0.40%    passed    100.00%
#  333  USA/MI-UM-10036332093/2020    2.85%    passed     99.83%
#  334  USA/MI-UM-10036118316/2020    0.66%    passed     99.98%
#  335  USA/MI-UM-10035824100/2020    1.81%    passed     99.97%
#  336  USA/MI-UM-10036299717/2020    2.47%    passed     99.91%
#  337  USA/MI-UM-10035956808/2020    0.40%    passed    100.00%
#  338  USA/MI-UM-10035980880/2020    0.40%    passed    100.00%
#  339  USA/MI-UM-10035963996/2020    1.87%    passed     99.99%
#  340  USA/MI-UM-2006S000964/2020    1.66%    passed     99.98%
#  341  USA/MI-UM-10035869177/2020    0.41%    passed     99.98%
#  342  USA/MI-UM-10035843632/2020    0.40%    passed     99.98%
#  343  USA/MI-UM-10035757569/2020    0.40%    passed     99.99%
#  344  USA/MI-UM-10036421781/2020    1.44%    passed     99.91%
#  345  USA/MI-UM-10035736384/2020    0.40%    passed     99.99%
#  346  USA/MI-UM-10035712935/2020    0.40%    passed     99.99%
#  347  USA/MI-UM-10035893881/2020    0.40%    passed     99.99%
#  348  USA/MI-UM-10036102177/2020    0.75%    passed     99.96%
#  349  USA/MI-UM-10035908071/2020    0.40%    passed     99.99%
#  350  USA/MI-UM-10036206650/2020    0.40%    passed    100.00%
#  351  USA/MI-UM-10035685450/2020    1.13%    passed     99.99%
#  352  USA/MI-UM-10035555295/2020    0.40%    passed    100.00%
#  353  USA/MI-UM-10036226294/2020    0.63%    passed    100.00%
#  354  USA/MI-UM-10036074663/2020    0.40%    passed     99.99%
#  355  USA/MI-UM-10035704378/2020    0.40%    passed    100.00%
#  356  USA/MI-UM-10035987523/2020    0.40%    passed    100.00%
#  357  USA/MI-UM-10035692188/2020    1.94%    passed     99.84%
#  358  USA/MI-UM-10035711830/2020    0.40%    passed    100.00%
#  359  USA/MI-UM-10035822253/2020    0.40%    passed    100.00%
#  360  USA/MI-UM-10035864364/2020    1.74%    passed     99.98%
#  361  USA/MI-UM-10036064450/2020    0.40%    passed    100.00%
#  362  USA/MI-UM-10035892209/2020    0.47%    passed    100.00%
#  363  USA/MI-UM-10035853858/2020    1.13%    passed     99.98%
#  364  USA/MI-UM-10035747436/2020    0.40%    passed    100.00%
#  365  USA/MI-UM-10035731267/2020    0.40%    passed    100.00%
#  366  USA/MI-UM-10035702532/2020    0.40%    passed     99.99%
#  367  USA/MI-UM-10035701578/2020    1.13%    passed     99.99%
#  368  USA/MI-UM-10036250932/2020    0.40%    passed    100.00%
#  369  USA/MI-UM-10036422360/2020    1.74%    passed     99.98%
#  370  USA/MI-UM-10036424368/2020    0.40%    passed    100.00%
#  371  USA/MI-UM-10036467524/2020    1.13%    passed    100.00%
#  372  USA/MI-UM-10035696298/2020    0.75%    passed     99.97%
#  373  USA/MI-UM-10035727656/2020    0.50%    passed    100.00%
#  374  USA/MI-UM-10035812504/2020    0.40%    passed    100.00%
#  375  USA/MI-UM-10035637067/2020    0.40%    passed    100.00%
#  376  USA/MI-UM-10035663652/2020    1.33%    passed     99.96%
#  377  USA/MI-UM-10035703434/2020    0.40%    passed    100.00%
#  378  USA/MI-UM-10035726990/2020    0.40%    passed    100.00%
#  379  USA/MI-UM-10035725364/2020    2.71%    passed     99.96%
#  380  USA/MI-UM-10035886189/2020    0.40%    passed    100.00%
#  381  USA/MI-UM-10035926038/2020    0.40%    passed    100.00%
#  382  USA/MI-UM-10035862473/2020    0.74%    passed     99.99%
#  383  USA/MI-UM-10035926031/2020    0.41%    passed    100.00%
#  384  USA/MI-UM-10035754891/2020    0.74%    passed    100.00%
#  385  USA/MI-UM-10035981014/2020    0.40%    passed    100.00%
#  386  USA/MI-UM-10036005983/2020    2.15%    passed     99.83%
#  387  USA/MI-UM-10036173189/2020    0.40%    passed     99.99%
#  388  USA/MI-UM-10035711552/2020    0.40%    passed     99.99%
#  389  USA/MI-UM-10035890097/2020    0.40%    passed     99.99%
#  390  USA/MI-UM-10036394525/2020    0.49%    passed    100.00%
#  391  USA/MI-UM-10036112787/2020    0.40%    passed    100.00%
#  392  USA/MI-UM-10036319590/2020    0.40%    passed    100.00%
#  393  USA/MI-UM-10036400561/2020    0.50%    passed     99.99%
#  394  USA/MI-UM-10036442334/2020    0.75%    passed     99.98%
#  395  USA/MI-UM-10035868153/2020    0.85%    passed    100.00%
#  396  USA/MI-UM-10036024406/2020    0.40%    passed     99.99%
#  397  USA/MI-UM-10036404849/2020    1.97%    passed     99.83%
#  398  USA/MI-UM-10034244391/2020    2.74%    passed     99.49%
#  399  USA/MI-UM-10033798803/2020    1.14%    passed    100.00%
#  400  USA/MI-UM-10033818339/2020    0.41%    passed     99.96%
#  401  USA/MI-UM-10033854135/2020    0.48%    passed    100.00%
#  402  USA/MI-UM-10036021679/2020    0.40%    passed     99.99%
#  403  USA/MI-UM-2006S001014/2020    0.78%    passed     99.98%
#  404  USA/MI-UM-10033834090/2020    0.43%    passed    100.00%
#  405  USA/MI-UM-10036310651/2020    0.53%    passed    100.00%
#  406  USA/MI-UM-10035641365/2020    0.50%    passed    100.00%
#  407  USA/MI-UM-10036004716/2020    1.13%    passed    100.00%
#  408  USA/MI-UM-10036297467/2020    0.40%    passed     99.98%
#  409  USA/MI-UM-10035713127/2020    1.13%    passed     99.99%
#  410  USA/MI-UM-10035713605/2020    0.40%    passed    100.00%
#  411  USA/MI-UM-10035711854/2020    0.40%    passed    100.00%
#  412  USA/MI-UM-10035750305/2020    0.66%    passed     99.99%
#  413  USA/MI-UM-10035945885/2020    0.75%    passed     99.99%
#  414  USA/MI-UM-10035923993/2020    1.13%    passed     99.99%
#  415  USA/MI-UM-10036404933/2020    0.75%    passed     99.99%
#  416  USA/MI-UM-10036428684/2020    1.43%    passed     99.99%
#  417  USA/MI-UM-10036132415/2020    2.26%    passed     99.96%
#  418  USA/MI-UM-10036155827/2020    0.40%    passed     99.99%
#  419  USA/MI-UM-10036195123/2020    0.40%    passed     99.99%
#  420  USA/MI-UM-10036156518/2020    2.07%    passed     99.67%
#  421  USA/MI-UM-10036372963/2020    0.40%    passed     99.99%
#  422  USA/MI-UM-10036099219/2020    0.40%    passed     99.99%
#  423  USA/MI-UM-10036188357/2020    0.68%    passed     99.97%
#  424  USA/MI-UM-10036370482/2020    0.40%    passed    100.00%
#  425  USA/MI-UM-10036444936/2020    1.16%    passed     99.99%
#  426  USA/MI-UM-10036132232/2020    1.83%    passed     99.63%
#  427  USA/MI-UM-10036132857/2020    0.40%    passed     99.99%
#  428  USA/MI-UM-10035702585/2020    0.98%    passed     99.92%
#  429  USA/MI-UM-MH27428/2020        0.98%    passed     99.93%
#  430  USA/MI-UM-10036165196/2020    0.40%    passed     99.98%
#  431  USA/MI-UM-10035702357/2020    0.66%    passed     99.99%
#  432  USA/MI-UM-10035685254/2020    0.66%    passed     99.99%
#  433  USA/MI-UM-10035615810/2020    0.40%    passed     99.99%
#  434  USA/MI-UM-10035711872/2020    0.40%    passed     99.99%
#  435  USA/MI-UM-10035701585/2020    0.42%    passed    100.00%
#  436  USA/MI-UM-10035665912/2020    0.75%    passed     99.99%
#  437  USA/MI-UM-10035685395/2020    0.59%    passed    100.00%
#  438  USA/MI-UM-10035683340/2020    1.13%    passed     99.92%
#  439  USA/MI-UM-10035692627/2020    0.40%    passed     99.97%
#  440  USA/MI-UM-10035624217/2020    2.49%    passed     99.88%
#  441  USA/MI-UM-10035739693/2020    0.40%    passed     99.99%
#  442  USA/MI-UM-10035772246/2020    0.75%    passed     99.99%
#  443  USA/MI-UM-10035977253/2020    0.40%    passed     99.99%
#  444  USA/MI-UM-10036033548/2020    0.75%    passed     99.99%
#  445  USA/MI-UM-10035790107/2020    0.40%    passed     99.99%
#  446  USA/MI-UM-10035803894/2020    0.40%    passed     99.99%
#  447  USA/MI-UM-10035790102/2020    0.40%    passed     99.99%
#  448  USA/MI-UM-10035986324/2020    0.40%    passed     99.98%
#  449  USA/MI-UM-10036166894/2020    0.66%    passed     99.97%
#  450  USA/MI-UM-10036150256/2020    0.40%    passed     99.97%
#  451  USA/MI-UM-10036205311/2020    0.40%    passed     99.98%
#  452  USA/MI-UM-10036296398/2020    0.40%    passed     99.98%
#  453  USA/MI-UM-10036369993/2020    1.13%    passed     99.92%
#  454  USA/MI-UM-10036305857/2020    0.40%    passed     99.98%
#  455  USA/MI-UM-10036119854/2020    0.40%    passed     99.99%
#  456  USA/MI-UM-10036287406/2020    0.40%    passed    100.00%
#  457  USA/MI-UM-10036329145/2020    1.13%    passed     99.98%
#  458  USA/MI-UM-10035804797/2020    0.43%    passed    100.00%
#  459  USA/MI-UM-10036130933/2020    0.40%    passed    100.00%
#  460  USA/MI-UM-10036077350/2020    0.75%    passed     99.99%
#  461  USA/MI-UM-10036116103/2020    1.13%    passed     99.91%
#  462  USA/MI-UM-10036116407/2020    0.40%    passed     99.98%
#  463  USA/MI-UM-10036168091/2020    0.40%    passed     99.98%
#  464  USA/MI-UM-10036307468/2020    0.75%    passed     99.99%
#  465  USA/MI-UM-10036150579/2020    0.40%    passed     99.97%
#  466  USA/MI-UM-10036396974/2020    1.13%    passed     99.88%
#  467  USA/MI-UM-10036117605/2020    0.40%    passed     99.98%
#  468  USA/MI-UM-10036381403/2020    0.40%    passed     99.99%
#  469  USA/MI-UM-10036055944/2020    1.13%    passed     99.94%
#  470  USA/MI-UM-10036005251/2020    1.13%    passed     99.94%
#  471  USA/MI-UM-10036001045/2020    1.13%    passed     99.94%
#  472  USA/MI-UM-10036005973/2020    0.40%    passed     99.98%
#  473  USA/MI-UM-10035994708/2020    0.75%    passed     99.98%
#  474  USA/MI-UM-10035681090/2020    1.13%    passed     99.95%
#  475  USA/MI-UM-10036347220/2020    1.13%    passed     99.96%
#  476  USA/MI-UM-10036444607/2020    2.03%    passed     99.99%
#  477  USA/MI-UM-10036306472/2020    0.40%    passed     99.95%
#  478  USA/MI-UM-10036346883/2020    1.47%    passed     99.67%
#  479  USA/MI-UM-10035531897/2020    0.40%    passed    100.00%
#  480  USA/MI-UM-10036281666/2020    0.40%    passed    100.00%
#  481  USA/MI-UM-10036242970/2020    0.40%    passed    100.00%
#  482  USA/MI-UM-10036310581/2020    1.71%    passed     99.73%
#  483  USA/MI-UM-10036310045/2020    2.50%    passed     99.92%
#  484  USA/MI-UM-10036284170/2020    0.40%    passed    100.00%
#  485  USA/MI-UM-10036322746/2020    1.83%    passed     99.77%
#  486  USA/MI-UM-10036150967/2020    0.50%    passed     99.97%
#  487  USA/MI-UM-10036284225/2020    0.45%    passed     99.99%
#  488  USA/MI-UM-10036207074/2020    0.42%    passed     99.99%
#  489  USA/MI-UM-10036339633/2020    0.42%    passed     99.99%
#  490  USA/MI-UM-10036361683/2020    0.43%    passed     99.99%
#  491  USA/MI-UM-10036322844/2020    2.87%    passed     99.78%
#  492  USA/MI-UM-10036386932/2020    0.77%    passed     99.90%
#  493  USA/MI-UM-10036429642/2020    0.70%    passed     99.94%
#  494  USA/MI-UM-10036429659/2020    1.15%    passed     99.81%
#  495  USA/MI-UM-10036469028/2020    1.17%    passed     99.82%
#  496  USA/MI-UM-10036468967/2020    1.15%    passed     99.82%
#  497  USA/MI-UM-10036413655/2020    1.34%    passed     99.74%
#  498  USA/MI-UM-10036454184/2020    2.68%    passed     99.90%
#  499  USA/MI-UM-10035622031/2020    0.40%    passed     99.94%
#  500  USA/MI-UM-10036396903/2020    2.48%    passed     99.87%
#  501  USA/MI-UM-10036438245/2020    1.36%    passed     99.98%
#  502  USA/MI-UM-10036139493/2020    0.40%    passed     99.99%
#  503  USA/MI-UM-10036212950/2020    0.40%    passed     99.99%
#  504  USA/MI-UM-10036312532/2020    0.67%    passed     99.96%
#  505  USA/MI-UM-10036119783/2020    0.40%    passed     99.99%
#  506  USA/MI-UM-10036128032/2020    0.40%    passed     99.98%
#  507  USA/MI-UM-10036335555/2020    0.96%    passed     99.96%
#  508  USA/MI-UM-10036309295/2020    1.26%    passed     99.32%
#  509  USA/MI-UM-10036446820/2020    2.71%    passed     99.96%
#  510  USA/MI-UM-10035907994/2020    0.40%    passed     99.97%
#  511  USA/MI-UM-10036416305/2020    0.96%    passed     99.99%
#  512  USA/MI-UM-10036187521/2020    0.40%    passed     99.96%
#  513  USA/MI-UM-10035727642/2020    1.62%    passed     99.72%
#  514  USA/MI-UM-10035946104/2020    2.56%    passed     99.98%
#  515  USA/MI-UM-10035757349/2020    0.40%    passed    100.00%
#  516  USA/MI-UM-MH27682/2020        1.13%    passed    100.00%
#  517  USA/MI-UM-10035755495/2020    0.75%    passed     99.99%
#  518  USA/MI-UM-10036092704/2020    1.42%    passed     99.96%
#  519  USA/MI-UM-10036381452/2020    1.06%    passed     99.93%
#  520  USA/MI-UM-10036422279/2020    1.13%    passed     99.97%
#  521  USA/MI-UM-10036036877/2020    0.40%    passed     99.98%
#  522  USA/MI-UM-10036453509/2020    1.74%    passed     99.98%
#  523  USA/MI-UM-10036331190/2020    1.14%    passed     99.99%
#  524  USA/MI-UM-10036002831/2020    0.75%    passed     99.99%
#  525  USA/MI-UM-10036277128/2020    0.46%    passed     99.96%
#  526  USA/MI-UM-10036434968/2020    0.75%    passed     99.97%
#  527  USA/MI-UM-2006S000851/2020    0.40%    passed     99.90%
#  528  USA/MI-UM-2006S000881/2020    0.40%    passed     99.89%
#  529  USA/MI-UM-2006S000913/2020    1.13%    passed     99.96%
#  530  USA/MI-UM-2006S001093/2020    0.40%    passed     99.89%
#  531  USA/MI-UM-2006S000954/2020    0.75%    passed     99.87%
#  532  USA/MI-UM-2006S000888/2020    1.24%    passed     99.98%
#  533  USA/MI-UM-2006S000912/2020    2.68%    passed     99.86%
#  534  USA/MI-UM-10036346836/2020    0.63%    passed     99.99%
#  535  USA/MI-UM-10036391877/2020    0.42%    passed    100.00%
#  536  USA/MI-UM-10036434093/2020    0.84%    passed     99.99%
#  537  USA/MI-UM-10035741674/2020    0.50%    passed     99.99%
#  538  USA/MI-UM-10035734995/2020    0.84%    passed     99.99%
#  539  USA/MI-UM-10035733673/2020    1.70%    passed     99.82%
#  540  USA/MI-UM-10036440713/2020    2.06%    passed    100.00%
#  541  USA/MI-UM-10036443590/2020    2.65%    passed     99.93%
#  542  USA/MI-UM-10036423734/2020    1.08%    passed     99.99%
#  543  USA/MI-UM-10036399786/2020    0.40%    passed     99.95%
#  544  USA/MI-UM-10036457372/2020    0.40%    passed     99.95%
#  545  USA/MI-UM-10036345655/2020    0.40%    passed     99.95%
#  546  USA/MI-UM-10036428041/2020    0.40%    passed     99.95%
#  547  USA/MI-UM-10036409812/2020    0.40%    passed     99.95%
#  548  USA/MI-UM-10036448224/2020    0.50%    passed     99.97%
#  549  USA/MI-UM-10036448245/2020    1.13%    passed     99.99%
#  550  USA/MI-UM-10036396778/2020    0.40%    passed     99.95%
#  551  USA/MI-UM-10036397118/2020    2.03%    passed     99.99%
#  552  USA/MI-UM-10035704779/2020    2.45%    passed     99.87%
#  553  USA/MI-UM-10036210275/2020    1.11%    passed     99.94%
#  554  USA/MI-UM-10035667510/2020    1.11%    passed     99.88%
#  555  USA/MI-UM-10035748873/2020    0.40%    passed     99.98%
#  556  USA/MI-UM-10035955997/2020    1.13%    passed    100.00%
#  557  USA/MI-UM-10035989687/2020    0.40%    passed     99.98%
#  558  USA/MI-UM-10035956870/2020    0.40%    passed     99.98%
#  559  USA/MI-UM-10035894711/2020    0.50%    passed     99.99%
#  560  USA/MI-UM-10036033491/2020    0.40%    passed     99.99%
#  561  USA/MI-UM-10035884804/2020    0.43%    passed     99.99%
#  562  USA/MI-UM-10036381059/2020    0.75%    passed     99.99%
#  563  USA/MI-UM-10035665108/2020    0.41%    passed    100.00%
#  564  USA/MI-UM-10035638988/2020    0.73%    passed     99.96%
#  565  USA/MI-UM-10035702306/2020    2.07%    passed     99.24%
#  566  USA/MI-UM-10035988472/2020    1.13%    passed     99.98%
#  567  USA/MI-UM-10036447294/2020    2.20%    passed     99.88%
#  568  USA/MI-UM-10035752970/2020    0.40%    passed     99.97%
#  569  USA/MI-UM-10035851052/2020    1.04%    passed     99.94%
#  570  USA/MI-UM-10035986675/2020    1.48%    passed     99.85%
#  571  USA/MI-UM-10036100373/2020    0.50%    passed     99.97%
#  572  USA/MI-UM-10036246523/2020    0.40%    passed     99.96%
#  573  USA/MI-UM-10036371442/2020    1.73%    passed     99.92%
#  574  USA/MI-UM-10036454655/2020    2.48%    passed     99.93%
#  575  USA/MI-UM-10036335706/2020    1.27%    passed     99.89%
#  576  USA/MI-UM-10036277659/2020    2.15%    passed     99.98%
#  577  USA/MI-UM-10035769699/2020    0.40%    passed     99.99%
#  578  USA/MI-UM-10035905827/2020    0.40%    passed     99.98%
#  579  USA/MI-UM-10036367756/2020    1.15%    passed     99.98%
#  580  USA/MI-UM-10036415960/2020    0.42%    passed     99.97%
#  581  USA/MI-UM-10036137935/2020    1.62%    passed     99.38%
#  582  USA/MI-UM-10036147209/2020    2.53%    passed     99.85%
#  583  USA/MI-UM-10036310636/2020    2.30%    passed     99.77%
#  584  USA/MI-UM-10035921670/2020    2.29%    passed     99.88%
#  585  USA/MI-UM-10036287420/2020    2.85%    passed     99.79%
#  586  USA/MI-UM-10036127680/2020    0.96%    passed     99.87%
#  587  USA/MI-UM-10036429696/2020    2.45%    passed     99.99%
#  588  USA/MI-UM-10036287673/2020    1.33%    passed     99.53%
#  589  USA/MI-UM-10036223985/2020    0.78%    passed     99.73%
#  590  USA/MI-UM-10036434045/2020    2.55%    passed     99.96%
#  591  USA/MI-UM-10036427017/2020    1.40%    passed     99.99%
#  592  USA/MI-UM-10036003560/2020    1.75%    passed     99.67%
# ****  TOTAL                         0.97%  0 sequences failed composition chi2 test (p-value<5%; df=3)
# NOTE: USA/MI-UM-2006S000915/2020 is identical to USA/MI-UM-2006S000850/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-2006S000876/2020 is identical to USA/MI-UM-2006S000861/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-2006S000866/2020 is identical to USA/MI-UM-2006S000864/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-2006S001118/2020 is identical to USA/MI-UM-2006S000969/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-2006S005728/2020 is identical to USA/MI-UM-2006S001095/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10033815825/2020 is identical to USA/MI-UM-2006S000907/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10033767074/2020 is identical to USA/MI-UM-2006S000956/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10033792343/2020 is identical to USA/MI-UM-10033792025/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10033973539/2020 is identical to USA/MI-UM-2006S001102/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10033828729/2020 is identical to USA/MI-UM-2006S000857/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035681864/2020 is identical to USA/MI-UM-10035692136/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035733857/2020 is identical to USA/MI-UM-10035752975/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035889322/2020 is identical to USA/MI-UM-10035806702/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035872711/2020 is identical to USA/MI-UM-10035862042/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035952713/2020 is identical to USA/MI-UM-10035955134/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035929654/2020 is identical to USA/MI-UM-10035942254/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036115045/2020 is identical to USA/MI-UM-10036079833/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036138856/2020 is identical to USA/MI-UM-10036061167/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036329024/2020 is identical to USA/MI-UM-10036024704/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036110847/2020 is identical to USA/MI-UM-10036001658/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036322730/2020 is identical to USA/MI-UM-10036286140/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036324614/2020 is identical to USA/MI-UM-10036333448/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036396939/2020 is identical to USA/MI-UM-10036477051/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035813057/2020 is identical to USA/MI-UM-10035725747/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-MH27455/2020 is identical to USA/MI-UM-10036133006/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035980880/2020 is identical to USA/MI-UM-10035956808/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035893881/2020 is identical to USA/MI-UM-10035712935/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036064450/2020 is identical to USA/MI-UM-10035822253/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035731267/2020 is identical to USA/MI-UM-10035747436/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035926038/2020 is identical to USA/MI-UM-10035886189/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035890097/2020 is identical to USA/MI-UM-10035711552/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036319590/2020 is identical to USA/MI-UM-10036112787/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035711854/2020 is identical to USA/MI-UM-10035713605/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036195123/2020 is identical to USA/MI-UM-10036155827/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035685254/2020 is identical to USA/MI-UM-10035702357/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035711872/2020 is identical to USA/MI-UM-10035615810/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035977253/2020 is identical to USA/MI-UM-10035739693/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036033548/2020 is identical to USA/MI-UM-10035772246/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035803894/2020 is identical to USA/MI-UM-10035790107/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036296398/2020 is identical to USA/MI-UM-10036205311/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036307468/2020 is identical to USA/MI-UM-10036077350/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036168091/2020 is identical to USA/MI-UM-10036116407/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036242970/2020 is identical to USA/MI-UM-10036281666/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036339633/2020 is identical to USA/MI-UM-10036207074/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10036457372/2020 is identical to USA/MI-UM-10036399786/2020 but kept for subsequent analysis
# NOTE: USA/MI-UM-10035956870/2020 is identical to USA/MI-UM-10035989687/2020 but kept for subsequent analysis
# NOTE: 62 identical sequences (see below) will be ignored for subsequent analysis
# NOTE: USA/MI-UM-2006S000935/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S001097/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S001114/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S001135/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S005725/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033759038/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033760952/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033768049/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033768108/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033774911/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033775516/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033781516/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033781702/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033783681/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033785805/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033793198/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033798318/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033808660/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033809081/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033811348/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033851497/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10034005736/2020 (identical to USA/MI-UM-2006S000850/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000880/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000891/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000897/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000898/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000911/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000922/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000981/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033793415/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033797804/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033871564/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-MH27541/2020 (identical to USA/MI-UM-2006S000861/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000882/2020 (identical to USA/MI-UM-2006S000864/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000899/2020 (identical to USA/MI-UM-2006S000864/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000931/2020 (identical to USA/MI-UM-2006S000864/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S000984/2020 (identical to USA/MI-UM-2006S000864/2020) is ignored but added at the end
# NOTE: USA/MI-UM-2006S001057/2020 (identical to USA/MI-UM-2006S000864/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10033833216/2020 (identical to USA/MI-UM-2006S000864/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036147927/2020 (identical to USA/MI-UM-10035752975/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10035849697/2020 (identical to USA/MI-UM-10035806702/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10035836175/2020 (identical to USA/MI-UM-10035806702/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10035863299/2020 (identical to USA/MI-UM-10035806702/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10035923573/2020 (identical to USA/MI-UM-10035955134/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10035923574/2020 (identical to USA/MI-UM-10035955134/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036396949/2020 (identical to USA/MI-UM-10036079833/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036249409/2020 (identical to USA/MI-UM-10036024704/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036253517/2020 (identical to USA/MI-UM-10036024704/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036282773/2020 (identical to USA/MI-UM-10036024704/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036312721/2020 (identical to USA/MI-UM-10036024704/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036335546/2020 (identical to USA/MI-UM-10036024704/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036138458/2020 (identical to USA/MI-UM-10036001658/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036399783/2020 (identical to USA/MI-UM-10036001658/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036457442/2020 (identical to USA/MI-UM-10036333448/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036429589/2020 (identical to USA/MI-UM-10036333448/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10035768201/2020 (identical to USA/MI-UM-10035725747/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036276912/2020 (identical to USA/MI-UM-10036133006/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10035790102/2020 (identical to USA/MI-UM-10035790107/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036284170/2020 (identical to USA/MI-UM-10036281666/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036345655/2020 (identical to USA/MI-UM-10036399786/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036428041/2020 (identical to USA/MI-UM-10036399786/2020) is ignored but added at the end
# NOTE: USA/MI-UM-10036409812/2020 (identical to USA/MI-UM-10036399786/2020) is ignored but added at the end
# Alignment was printed to aligned.fa.uniqueseq.phy
#
# For your convenience alignment with unique sequences printed to aligned.fa.uniqueseq.phy
#
# NOTE: Restoring information from model checkpoint file aligned.fa.model.gz
#
# CHECKPOINT: Initial tree restored
# Perform fast likelihood tree search using GTR+I+G model...
# CHECKPOINT: Tree restored, LogL: -51989.193
# NOTE: ModelFinder requires 229 MB RAM!
# ModelFinder will test up to 286 DNA models (sample size: 29903) ...
#  No. Model         -LnL         df  AIC          AICc         BIC
#   1  GTR+F         52208.254    1065 106546.508   106625.246   115392.093
#   2  GTR+F+I       51991.805    1066 106115.610   106194.499   114969.501
#   3  GTR+F+G4      52020.440    1066 106172.879   106251.768   115026.771
#   4  GTR+F+I+G4    51989.147    1067 106112.294   106191.334   114974.491
#   5  GTR+F+R2      51989.751    1067 106113.501   106192.541   114975.698
#   6  GTR+F+R3      51952.646    1069 106043.292   106122.634   114922.101
#   7  GTR+F+R4      51952.724    1071 106047.448   106127.092   114942.867
#  19  SYM+R3        52979.160    1066 108090.320   108169.209   116944.211
#  32  TVM+F+R3      52073.624    1068 106283.248   106362.439   115153.751
#  45  TVMe+R3       53107.303    1065 108344.605   108423.343   117190.191
#  58  TIM3+F+R3     52087.718    1067 106309.436   106388.476   115171.633
#  71  TIM3e+R3      53089.625    1064 108307.251   108385.839   117144.531
#  84  TIM2+F+R3     52030.161    1067 106194.321   106273.361   115056.518
#  97  TIM2e+R3      53087.760    1064 108303.520   108382.108   117140.799
# 110  TIM+F+R3      52014.064    1067 106162.129   106241.169   115024.326
# 123  TIMe+R3       53054.069    1064 108236.138   108314.726   117073.418
# 136  TPM3u+F+R3    52211.251    1066 106554.501   106633.390   115408.393
# 149  TPM3+F+R3     52211.251    1066 106554.501   106633.390   115408.392
# 162  TPM2u+F+R3    52154.889    1066 106441.778   106520.667   115295.669
# 175  TPM2+F+R3     52154.889    1066 106441.778   106520.667   115295.669
# 188  K3Pu+F+R3     52141.617    1066 106415.234   106494.123   115269.125
# 201  K3P+R3        53183.686    1063 108493.373   108571.810   117322.347
# 214  TN+F+R3       52116.322    1066 106364.644   106443.533   115218.535
# 227  TNe+R3        53149.225    1063 108424.450   108502.888   117253.424
# 240  HKY+F+R3      52243.686    1065 106617.371   106696.110   115462.957
# 253  K2P+R3        53278.979    1062 108681.959   108760.246   117502.627
# 266  F81+F+R3      52646.918    1064 107421.835   107500.423   116259.115
# 279  JC+R3         53672.316    1061 109466.633   109544.770   118278.996
# Akaike Information Criterion:           GTR+F+R3
# Corrected Akaike Information Criterion: GTR+F+R3
# Bayesian Information Criterion:         GTR+F+R3
# Best-fit model: GTR+F+R3 chosen according to BIC
#
# All model information printed to aligned.fa.model.gz
# CPU time for ModelFinder: 701.716 seconds (0h:11m:41s)
# Wall-clock time for ModelFinder: 148.426 seconds (0h:2m:28s)
#
# NOTE: 68 MB RAM (0 GB) is required!
# Estimate model parameters (epsilon = 0.100)
# 1. Initial log-likelihood: -51952.646
# Optimal log-likelihood: -51952.594
# Rate parameters:  A-C: 0.19831  A-G: 0.85026  A-T: 0.06543  C-G: 0.10648  C-T: 3.06606  G-T: 1.00000
# Base frequencies:  A: 0.299  C: 0.183  G: 0.196  T: 0.321
# Site proportion and rates:  (0.512,0.510) (0.469,0.711) (0.019,20.888)
# Parameters optimization took 1 rounds (0.594 sec)
# Computing ML distances based on estimated model parameters... 7.571 sec
# Computing BIONJ tree...
# 0.293 seconds
# Log-likelihood of BIONJ tree: -51982.770
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Generating 98 parsimony trees... 9.067 second
# Computing log-likelihood of 98 initial trees ... 7.018 seconds
# Current best score: -51945.667
#
# Do NNI search on 20 best initial trees
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 1: -51935.331
# ^C
